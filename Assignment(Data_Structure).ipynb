# %% [markdown]
# Theoritical Questions

# %% [markdown]
# Q1. What are data structures, and why are they important?
# ANS:- Data structures are ways to organize, store, process, and
#       retrieve data. They are essential for managing data efficiently, especially large amounts of data.
#
#       Why are data structures important?
#       1. Access and work with data
#          Data structures make it easier for users to find and work with the data they need.
#       2. Optimize code
#          Data structures help programmers optimize their code and make it more efficient.
#       3. Improve problem-solving
#          Learning data structures can help improve problem-solving abilities.
#       4. Prepare for a career in technology
#          Learning data structures and algorithms is an important skill for aspiring programmers and can lead to job opportunities in tech companies
#
#
#
# Q2.  Explain the difference between mutable and immutable data types
#      with examples.
# ANS:- The main difference between mutable and immutable data types is
#       that mutable data types can be changed after creation, while immutable data types cannot
#
#       Mutable
#       Data types that can be changed after creation include lists, dictionaries, and sets. For example, you can add, remove, or update the values in a list.
#
#       Immutable
#       Data types that cannot be changed after creation include strings and tuples. For example, the words in a printed book cannot be changed once they are printed.
#
#
# Q3. What are the main differences between lists and tuples in Python?
# ANS:- (Lists)
#       1. List are mutable.
#       2. List can be modified.
#       3. List are use square brackets.
#       4. List are low memory efficient.
#       5. List are faster time efficiency.
#       6. Lists support a wider range of methods, such as appending,
#          inserting, and removing elements.
#
#       (Tuple)
#       1. Tuple are immutable.
#       2. Tuple can not be modified.
#       3. Tuple are use paranthises brackets.
#       4. Tuple are high memory efficient.
#       5. Tuple are slightly faster.
#       6. Tuples provide basic operations that allow you to retrieve
#          information, like the length or index of a specific element.
#
#
# Q4. Describe how dictionaries store data.
# ANS:- Dictionaries are used to store data values in key:value pairs. A
#       dictionary is a collection which is ordered*, changeable and do not allow duplicates.
#       example:
#       d1 = {"Name": "Ram", "Age": "19", "Country": "India"}
#
#
# Q5. Why might you use a set instead of a list in Python?
# ANS:- One of the main advantages of using sets in Python is that they
#       are highly optimized for membership tests.
#       For example, sets do membership tests a lot more efficiently than lists.
#       python unique_fruits = {"apple", "banana", "apple"} # Duplicates are removed if "orange" in unique_fruits: # Checking membership print("Yes, orange is present").
#
#
# Q6. What is a string in Python, and how is it different from a list?
# ANS:- strings are used for representing textual data. A string is a
#       sequence of characters enclosed in either single quotes ('') or double quotes (“”). The Python language provides various built-in methods and functionalities to work with strings efficiently.
#       A list is a sequence of items, where each item could be anything (an integer, a float, a string, etc).
#
#
# Q7. How do tuples ensure data integrity in Python?
# ANS:- Tuples are immutable to ensure that their contents remain
#       constant throughout their lifecycle, guaranteeing data integrity and reliability. This immutability allows tuples to be used as keys in dictionaries and elements in sets, as they can be hashed.
#
#
# Q8. What is a hash table, and how does it relate to dictionaries in
#     Python?
# ANS:- A hash table is a data structure that stores key-value pairs,
#       where the key's hash value determines the bucket for that data. Hash tables are efficient and offer fast access to data.
#       Python's built-in dictionary data type is an implementation of a hash table. Dictionaries use a hash function to generate keys and store key-value pairs.
#
# Q9. Can lists contain different data types in Python?
# ANS:- lthough it's not really common, a list can also contain a mix of
#       Python types including strings, floats, and booleans.
#
# Q10. Explain why strings are immutable in Python.
# ANS:- Python strings are "immutable" which means they cannot be changed
#       after they are created (Java strings also use this immutable style). Since strings can't be changed, we construct *new* strings as we go to represent computed values.
#
# Q11. What advantages do dictionaries offer over lists for certain tasks?
# ANS:- So it is more efficient to use dictionaries for the searching of
#       elements as it can be carried out in a much faster manner. Lists are used when it is important to maintain the order of the elements and dealing with data that may get changed in the future.
#
# Q12. Describe a scenario where using a tuple would be preferable over a list.
# ANS:- Use a tuple if you need an immutable collection where the
#       elements won't change after creation. Tuples are generally faster and more memory-efficient than lists, making them better for fixed collections, especially as dictionary keys or when iteration speed is crucial.
#
# Q13. How do sets handle duplicate values in Python?
# ANS:- tems of a set in python are immutable (unchangeable), do not
#       duplicate values, and unordered. Thus, items in a set do not appear in a stipulated manner, i.e., they can appear in a different order every time it is used. Due to this, set items cannot be referred to by key or index.
#
# Q14. How does the “in” keyword work differently for lists and dictionaries?
# ANS:-The key of the dictionary is a unique value as well as the set,
#      and the execution time is about the same as for sets. On the other hand, dictionary values can be duplicated like a list. The execution time of in for values() is about the same as for lists. Key-value pairs are unique.
#
# Q15. Can you modify the elements of a tuple? Explain why or why not?
# ANS:- No, you cannot modify the elements of a tuple in Python.
#       because tuples are "immutable," meaning once created, their elements cannot be changed; if you try to alter a tuple element, you will receive a TypeError error.
#
#
# Q16. What is a nested dictionary, and give an example of its use case?
# ANS:- A nested dictionary is a collection of dictionaries within     another dictionary in Python. It's a powerful tool for representing data with multiple layers of organization. Here are some examples of how nested dictionaries can be used:
#
# nested_dict = { 'dictA': {'key_1': 'value_1'}, 'dictB': {'key_2': 'value_2'}}.
#
# Q17. Describe the time complexity of accessing elements in a dictionary.
# ANS:- The time complexity of retrieving a value by its key in a
#       dictionary is O(1). This is because dictionaries use a hash table internally which allows constant time lookup. Why O(1)? Hash tables use the hash of the key to find the memory location which enables direct access.
#
#
# Q18. In what situations are lists preferred over dictionaries?
# ANS:- If you need an ordered collection, like a sequence of user
#       actions, lists are your go-to. On the other hand, when you need quick look-ups, like mapping usernames to user data, dictionaries are invaluable.
#
# Q19. Why are dictionaries considered unordered, and how does that affect data retrieval?
# ANS:- Why are dictionaries considered unordered, and how does that
#       affect data retrieval.
#       Python's dictionary allows you to store key-value pairs, and then pass the dictionary a key to quickly retrieve its corresponding value.
#
#
# Q20. Explain the difference between a list and a dictionary in terms of data retrieval.
# ANS:-Python lists can store an ordered collection of items, or elements, of
#      varying types. They are often used to compile multiple items into a single, mutable variable, which is helpful for retrieving items, specifying outputs or performing calculations quickly.
#      Python lists can store an ordered collection of items, or elements, of varying types. They are often used to compile multiple items into a single, mutable variable, which is helpful for retrieving items, specifying outputs or performing calculations quickly.

# %% [markdown]
# Practical Questions

# %% [markdown]
# Q1. Write a code to create a string with your name and print it.

# %%
name = ("Pappu Kumar Thakur")
print("My Name is",name) # print of string
# Out:
# My Name is Pappu Kumar Thakur

# %% [markdown]
# Q2. Write a code to find the length of the string "Hello World".

# %%
str = "Hello World"
len(str) # length of str
# Out:
# 11

# %% [markdown]
# Q3. Write a code to slice the first 3 characters from the string "Python Programming".

# %%
str = "Python Programming"
str[0:3] # slice the 3 charaters in str
# Out:
# 'Pyt'

# %% [markdown]
# Q4. Write a code to convert the string "hello" to uppercase.

# %%
string = "hello"
string.upper() # convert the uppercase in string
# Out:
# 'HELLO'

# %% [markdown]
# Q5. Write a code to replace the word "apple" with "orange" in the string "I like apple".

# %%
string1 = "I like apple"
string1.replace("apple","orange") # replace the string1
# Out:
# 'I like orange'

# %% [markdown]
# Q6.  Write a code to create a list with numbers 1 to 5 and print it.

# %%
list = [1, 2, 3, 4, 5]
print("That is my first list")
list
# Out:
# That is my first list
# [1, 2, 3, 4, 5]

# %% [markdown]
# Q7. Write a code to append the number 10 to the list [1, 2, 3, 4].

# %%
list = [1, 2, 3, 4]
list.append(10) # append the number is 10 in the list
list
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# Q8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].

# %%
list1 = [1, 2, 3, 4, 5]
list1.remove(3) # remove the number 3 from the list1
list1
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# Q9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].

# %%
list2 = ['a', 'b', 'c', 'd']
list2[1] # access the second element in list2
# Out:
# 'b'

# %% [markdown]
# Q10. Write a code to reverse the list [10, 20, 30, 40, 50].

# %%
list3 = [10, 20, 30, 40, 50]
list3.reverse() # reverse the list in list3
list3
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# Q11. Write a code to create a tuple with the elements 10, 20, 30 and print it.

# %%
tuple = (10, 20,30)
print("That is my first tuple")
tuple
# Out:
# That is my first tuple
# (10, 20, 30)

# %% [markdown]
# Q12.Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').

# %%
tuple1  = ('apple', 'banana', 'cherry')
tuple1[0] # access the first element in tuple1
# Out:
# 'apple'

# %% [markdown]
# Q13.Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).

# %%
tuple2 = (1, 2, 3, 2, 4, 2)
tuple2.count(2) # count the number 2 in tuple2
# Out:
# 3

# %% [markdown]
# Q14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
tuple3 =  ('dog', 'cat', 'rabbit')
tuple3.index("cat") # find the index of the element in tuple3
# Out:
# 1

# %% [markdown]
# Q15. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').

# %%
tuple = ('apple', 'orange', 'banana')
"banana" in tuple # check the element is in the tuple
# Out:
# True

# %% [markdown]
# Q16. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.

# %%
set = {1, 2, 3, 4, 5}
print("That is my first set")
set
# Out:
# That is my first set
# {1, 2, 3, 4, 5}

# %% [markdown]
# Q17. rite a code to add the element 6 to the set {1, 2, 3, 4}.

# %%
set1 = {1, 2, 3, 4}
set1.add(6) #add te element 6 in set1
set1
# Out:
# {1, 2, 3, 4, 6}

# %% [markdown]
# Q18.  Write a code to create a tuple with the elements 10, 20, 30 and print it.

# %%
tuple = (10, 20,30)
tuple
# Out:
# (10, 20, 30)

# %% [markdown]
# Q19.Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').

# %%
tuple = ('apple', 'banana', 'cherry')
tuple[0] # access the first element in tuple1
# Out:
# 'apple'

# %% [markdown]
# Q20. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).

# %%
tuple = (1,2,3,2,4,2)
tuple2.count(2) # count the number 2 in tuple
tuple.count(2)
# Out:
# 3

# %% [markdown]
# Q21. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
tuple = ('dog', 'cat', 'rabbit')
tuple.index("cat") # find the index of the element in tuple
# Out:
# 1

# %% [markdown]
# Q22. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').

# %%
tuple = ('apple', 'orange', 'banana')
"banana" in tuple # check the element is in the tuple
# Out:
# True

# %% [markdown]
# Q23. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.

# %%
set = {1,2,3,4,5}
set
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Q24. Write a code to add the element 6 to the set {1, 2, 3, 4}.

# %%
set4 = {1,2,3,4}
set4.add(6) # add te element 6 in set4
set4
# Out:
# {1, 2, 3, 4, 6}
